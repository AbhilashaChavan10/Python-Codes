# %% [markdown]
# <a href="https://colab.research.google.com/github/AbhilashaChavan10/Python-Codes/blob/main/classNotes_16june24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
age = 25
balance = 25000.5
name = "Amit Patil"
password ="Admin @123$"

name.upper()

name.lower()

info = [25, 25000.5, "Amit Patil" , "Admin @123$"]

info[1]

data = {"age" : 25 ,  "name" : "Amit Patil"}

data

data = {"age" : 40 ,  "name" : "Amit Patil", "age" : 35}

data

x = [-2,2.4,3,6]
y = [-2,3.5,5,7]
import matplotlib.pyplot as plt
plt.plot(x,y,'+-')
